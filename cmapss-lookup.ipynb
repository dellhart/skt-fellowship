# %%
import os
import glob
import datetime

import numpy as np
import scipy
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

RAW_DATA_HOME = './rawdata'
RAW_CMAPSS_DATA_HOME = os.path.join(RAW_DATA_HOME, 'CMAPSSData')
RAW_TARGET_DATA_PATTERN = 'train_*3*'
RAW_TEST_DATA_PATTERN = 'test_*3*'
RUL_TEST_DATA_PATTERN = 'RUL_*3*'

RAW_DATA_FIND_PATTERN = os.path.join(RAW_CMAPSS_DATA_HOME, RAW_TARGET_DATA_PATTERN)
RAW_TEST_FIND_PATTERN = os.path.join(RAW_CMAPSS_DATA_HOME, RAW_TEST_DATA_PATTERN)
RUL_TEST_FIND_PATTERN = os.path.join(RAW_CMAPSS_DATA_HOME, RUL_TEST_DATA_PATTERN)

# %%
target = glob.glob(RAW_DATA_FIND_PATTERN)[0] # Lookup data 1
target_test = glob.glob(RAW_TEST_FIND_PATTERN)[0]

# %%
df = pd.read_csv(target, header=None, sep=' ')
df = df.drop([26, 27], axis=1) # drop garbage

# %%
df
# Out:
#         0    1       2       3      4       5       6        7        8   \
# 0        1    1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70  1400.60
# 1        1    2  0.0019 -0.0003  100.0  518.67  642.15  1591.82  1403.14
# 2        1    3 -0.0043  0.0003  100.0  518.67  642.35  1587.99  1404.20
# 3        1    4  0.0007  0.0000  100.0  518.67  642.35  1582.79  1401.87
# 4        1    5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85  1406.22
# ...    ...  ...     ...     ...    ...     ...     ...      ...      ...
# 20626  100  196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98  1428.63
# 20627  100  197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50  1433.58
# 20628  100  198  0.0004  0.0000  100.0  518.67  643.42  1602.46  1428.18
# 20629  100  199 -0.0011  0.0003  100.0  518.67  643.23  1605.26  1426.53
# 20630  100  200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38  1432.14
#
#           9   ...      16       17       18      19    20   21    22     23  \
# ...

# %%
d = df[df[0] == 1].iloc[:, 2:25].values
d = d - np.mean(d, axis=0)
plt.plot(d)

# %%
d = df[df[0] == 100].iloc[:, 2:25].values
d = d - np.mean(d, axis=0)

# %%
plt.plot(d)

# %%
df = pd.read_csv(target_test, header=None, sep=' ')
df = df.drop([26, 27], axis=1) # drop garbage
target_test
# Out:
# './rawdata/CMAPSSData/test_FD003.txt'

# %%
d = df[df[0] == 4].iloc[:, 2:25].values
d = d - np.mean(d, axis=0)

# %%
import seaborn as sns

sns.set(style='whitegrid')
plt.plot(d)
plt.title('FD003, Unit 4, RUL: 120')
plt.xlabel('Cycle')
plt.ylabel('Measurement')
plt.savefig('./outs/FD003-4-120.png', bbox_inches='tight')
plt.close()

# %%
d = df[df[0] == 24].iloc[:, 2:25].values
d = d - np.mean(d, axis=0)

# %%
plt.plot(d)
plt.title('FD003, Unit 24, RUL: 9')
plt.xlabel('Cycle')
plt.ylabel('Measurement')
plt.savefig('./outs/FD003-24-9.png', bbox_inches='tight')
plt.close()
